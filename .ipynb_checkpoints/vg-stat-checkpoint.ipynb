# %% [markdown]
# # Data Analysis
# ## Video Game Sales
# ### Raven Robertson
# ### September 03, 2019

# %%
import pandas as pd
from collections import Counter

# %%
game_data = pd.read_csv('vgsales.csv')

# %%
game_data
# Out:
#         Rank                                              Name Platform  \
# 0          1                                        Wii Sports      Wii
# 1          2                                 Super Mario Bros.      NES
# 2          3                                    Mario Kart Wii      Wii
# 3          4                                 Wii Sports Resort      Wii
# 4          5                          Pokemon Red/Pokemon Blue       GB
# ...      ...                                               ...      ...
# 16593  16596                Woody Woodpecker in Crazy Castle 5      GBA
# 16594  16597                     Men in Black II: Alien Escape       GC
# 16595  16598  SCORE International Baja 1000: The Official Game      PS2
# 16596  16599                                        Know How 2       DS
# 16597  16600                                  Spirits & Spells      GBA
#
#          Year         Genre   Publisher  NA_Sales  EU_Sales  JP_Sales  \
# ...

# %% [markdown]
# #### Which company is the most common video game publisher?

# %%
game_data.Publisher.mode()
# Out:
# 0    Electronic Arts
# dtype: object

# %% [markdown]
# #### What’s the most common platform?

# %%
game_data.Platform.mode()
# Out:
# 0    DS
# dtype: object

# %% [markdown]
# #### What about the most common genre?

# %%
game_data.Genre.mode()
# Out:
# 0    Action
# dtype: object

# %% [markdown]
# #### What are the top 20 highest grossing games?

# %%
top_sales = game_data[['Name', 'Global_Sales']]

# %%
top_sales.sort_values(by='Global_Sales', ascending=False).head(20)
# Out:
#                                             Name  Global_Sales
# 0                                     Wii Sports         82.74
# 1                              Super Mario Bros.         40.24
# 2                                 Mario Kart Wii         35.82
# 3                              Wii Sports Resort         33.00
# 4                       Pokemon Red/Pokemon Blue         31.37
# 5                                         Tetris         30.26
# 6                          New Super Mario Bros.         30.01
# 7                                       Wii Play         29.02
# 8                      New Super Mario Bros. Wii         28.62
# 9                                      Duck Hunt         28.31
# 10                                    Nintendogs         24.76
# 11                                 Mario Kart DS         23.42
# 12                   Pokemon Gold/Pokemon Silver         23.10
# 13                                       Wii Fit         22.72
# ...

# %% [markdown]
# #### For North American video game sales, what’s the median?

# %%
game_data.NA_Sales.median()
# Out:
# 0.08

# %% [markdown]
# ##### Provide a secondary output showing ‘about’ ten games surrounding the median sales output

# %%
game_data[(game_data['NA_Sales'] == 0.08)].head(10)
# Out:
#       Rank                                               Name Platform  \
# 446    447                                  Dragon Warrior IV      NES
# 497    498        World Soccer Winning Eleven 7 International      PS2
# 1617  1619                             Farming Simulator 2015       PC
# 1926  1928                          Pro Evolution Soccer 2008     X360
# 2067  2069  Winning Eleven: Pro Evolution Soccer 2007 (All...     X360
# 2373  2375                           Phantasy Star Portable 2      PSP
# 2579  2581                               The Sims 2: Castaway      PSP
# 3186  3188                                     SingStar Queen      PS2
# 3503  3505                                         Top Spin 3      PS3
# 3703  3705               Sonic & All-Stars Racing Transformed      PS3
#
#         Year         Genre                     Publisher  NA_Sales  EU_Sales  \
# 446   1990.0  Role-Playing              Enix Corporation      0.08      0.00
# ...

# %% [markdown]
# #### For the top-selling game of all time, how many standard deviations above/below the mean are its sales for North America?

# %%
top_sales.head(1)
# Out:
#          Name  Global_Sales
# 0  Wii Sports         82.74

# %%
top_seller = game_data[:1]
NASales = game_data['NA_Sales'].std()
deviation= top_seller['NA_Sales'] / NASales_std
# Out:
# Wii Sportsthe top selling game of all time, is 50.80306374875828 standard deviations above the average for North American Sales.
#    Rank        Name Platform    Year   Genre Publisher  NA_Sales  EU_Sales  \
# 0     1  Wii Sports      Wii  2006.0  Sports  Nintendo     41.49     29.02
#
#    JP_Sales  Other_Sales  Global_Sales
# 0      3.77         8.46         82.74

# %% [markdown]
# #### The Nintendo Wii seems to have outdone itself with games. How does its average number of sales compare with all of the other platforms?

# %%
wii = game_data['Global_Sales'].loc[game_data['Platform'] == 'Wii'].mean()
non_wii = game_data['Global_Sales'].loc[game_data['Platform'] != 'Wii'].mean()
# Out:
# the average of wii vs non-wii games is 0.6994037735849057 : 0.5233896418516336

# %% [markdown]
# #### Three additional questions:
